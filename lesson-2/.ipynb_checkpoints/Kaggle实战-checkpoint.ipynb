# %% [markdown]
# 1. 处理离散数据
# 2. 处理丢失的数据特征
# 3. 对数据进行标准化

# %% [markdown]
# #### 房价预测问题

# %%
import pandas as pd
import numpy as np

train = pd.read_csv('../kaggle-data/House Prices/train.csv')
test = pd.read_csv('../kaggle-data/House Prices/test.csv')

all_X = pd.concat((train.loc[:, 'MSSubClass': 'SaleCondition'], test.loc[:, 'MSSubClass': 'SaleCondition']))

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
all_X.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0    NaN
# 1         Lvl    AllPub       FR2      ...                 0        0    NaN
# 2         Lvl    AllPub    Inside      ...                 0        0    NaN
# 3         Lvl    AllPub    Corner      ...                 0        0    NaN
# 4         Lvl    AllPub       FR2      ...                 0        0    NaN
#
#   Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0   NaN         NaN       0       2    2008        WD         Normal
# 1   NaN         NaN       0       5    2007        WD         Normal
# 2   NaN         NaN       0       9    2008        WD         Normal
# 3   NaN         NaN       0       2    2006        WD        Abnorml
# 4   NaN         NaN       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %%
train.shape
# Out:
# (1460, 81)

# %%
test.shape
# Out:
# (1459, 80)

# %%
#数据标准化处理
numeric_feats = all_X.dtypes[all_X.dtypes != 'object'].index
all_X[numeric_feats] = all_X[numeric_feats].apply(lambda x : (x - x.mean()) / (x.std()))

# %%
# 把离散的数据点转成数值标签
all_X = pd.get_dummies(all_X, dummy_na=True)
all_X.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    0.067320    -0.184443 -0.217841     0.646073    -0.507197   1.046078
# 1   -0.873466     0.458096 -0.072032    -0.063174     2.187904   0.154737
# 2    0.067320    -0.055935  0.137173     0.646073    -0.507197   0.980053
# 3    0.302516    -0.398622 -0.078371     0.646073    -0.507197  -1.859033
# 4    0.067320     0.629439  0.518814     1.355319    -0.507197   0.947040
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2        ...          \
# 0      0.896679    0.523038    0.580708    -0.29303        ...
# 1     -0.395536   -0.569893    1.177709    -0.29303        ...
# 2      0.848819    0.333448    0.097840    -0.29303        ...
# 3     -0.682695   -0.569893   -0.494771    -0.29303        ...
# 4      0.753100    1.381770    0.468770    -0.29303        ...
#
#    SaleType_Oth  SaleType_WD  SaleType_nan  SaleCondition_Abnorml  \
# 0             0            1             0                      0
# 1             0            1             0                      0
# 2             0            1             0                      0
# 3             0            1             0                      1
# 4             0            1             0                      0
#
#    SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0                      0                     0                     0
# 1                      0                     0                     0
# 2                      0                     0                     0
# 3                      0                     0                     0
# 4                      0                     0                     0
#
#    SaleCondition_Normal  SaleCondition_Partial  SaleCondition_nan
# 0                     1                      0                  0
# 1                     1                      0                  0
# 2                     1                      0                  0
# 3                     0                      0                  0
# 4                     1                      0                  0
#
# [5 rows x 331 columns]

# %%
# 把缺失数据用本特征的平均值估计
all_X = all_X.fillna(all_X.mean())

# %%
# 转换数据格式
num_train = train.shape[0]

X_train = all_X[:num_train].as_matrix()
X_test = all_X[num_train:].as_matrix()
y_train = train.SalePrice.as_matrix()

# %%
train.size
# Out:
# 118260

# %%
num_train
# Out:
# 1460

# %%
X_train.size
# Out:
# 483260

# %%
X_test.size
# Out:
# 482929

# %%
# 转换为gluon的ndArray格式
from mxnet import ndarray as nd
from mxnet import autograd
from mxnet import gluon

X_train = nd.array(X_train)
y_train = nd.array(y_train)
y_train.reshape((num_train, 1))

X_test = nd.array(X_test)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xb
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xb

# %%
# 损失函数 平方误差
square_loss = gluon.loss.L2Loss()

# %%
# 比赛中测量结果的函数
def get_rmse_log(net, X_train, y_train):
    num_train = X_train.shape[0]
    clipped_preds = nd.clip(net(X_train), 1, float('inf'))
    return np.sqrt(2 * nd.sum(square_loss(nd.log(clipped_preds), nd.log(y_train))).asscalar()/ num_train)

# %%
# 定义模型
def get_net():
    net = gluon.nn.Sequential()
    with net.name_scope():
        net.add(gluon.nn.Flatten())
        net.add(gluon.nn.Dense(256, activation='relu'))
        net.add(gluon.nn.Dropout(0.5))
        net.add(gluon.nn.Dense(1))
    net.initialize()
    return net

# %%
# 训练函数
import matplotlib as mpl 
mpl.rcParams['figure.dpi'] = 120
import matplotlib.pyplot as plt

def train(net, X_train, y_train, X_test, y_test, epochs, verbose_epoch, learning_rate, weight_decay):
    train_loss = []
    if X_test is not None:
        test_loss = []
    batch_size = 150
    dataset_train = gluon.data.ArrayDataset(X_train, y_train)
    data_iter_train = gluon.data.DataLoader(dataset_train, batch_size, shuffle=True)
    trainer = gluon.Trainer(net.collect_params(), 'adam', {'learning_rate': learning_rate, 'wd': weight_decay})
    net.collect_params().initialize(force_reinit=True)
    for epoch in range(epochs):
        for data, label in data_iter_train:
            with autograd.record():
                output = net(data)
                loss = square_loss(output, label)
            loss.backward()
            trainer.step(batch_size)
            
            cur_train_loss = get_rmse_log(net, X_train, y_train)
        if epoch > verbose_epoch:
            print('epoch %d, train loss: %f' %(epoch, cur_train_loss))
        train_loss.append(cur_train_loss)
        if X_test is not None:
            cur_test_loss = get_rmse_log(net, X_test, y_test)
            test_loss.append(cur_test_loss)
    plt.plot(train_loss)
    plt.legend(['train'])
    if X_test is not None:
        plt.plot(test_loss)
        plt.legend(['train', 'test'])
    plt.show()
    if X_test is not None:
        return cur_train_loss, cur_test_loss
    else:
        return cur_train_loss

# %% [markdown]
# #### K折交叉验证
# 过度依赖训练数据集的误差来推断测试数据集的误差容易导致过拟合。事实上，当我们调参时，往往需要基于K折交叉验证。
# >在K折交叉验证中，我们把初始采样分割成K个子样本，一个单独的子样本被保留作为验证模型的数据，其他K-1个样本用来训练
#
# 我们关心K次验证模型的测试结果的平均值和训练误差的平均值，因此我们定义K折交叉验证函数如下：

# %%
def k_fold_cross_valid(k, epochs, verbose_epoch, X_train, y_train,
                       learning_rate, weight_decay):
    assert k > 1
    fold_size = X_train.shape[0] // k
    train_loss_sum = 0.0
    test_loss_sum = 0.0
    for test_i in range(k):
        X_val_test = X_train[test_i * fold_size: (test_i + 1) * fold_size, :]
        y_val_test = y_train[test_i * fold_size: (test_i + 1) * fold_size]

        val_train_defined = False
        for i in range(k):
            if i != test_i:
                X_cur_fold = X_train[i * fold_size: (i + 1) * fold_size, :]
                y_cur_fold = y_train[i * fold_size: (i + 1) * fold_size]
                if not val_train_defined:
                    X_val_train = X_cur_fold
                    y_val_train = y_cur_fold
                    val_train_defined = True
                else:
                    X_val_train = nd.concat(X_val_train, X_cur_fold, dim=0)
                    y_val_train = nd.concat(y_val_train, y_cur_fold, dim=0)
        net = get_net()
        train_loss, test_loss = train(
            net, X_val_train, y_val_train, X_val_test, y_val_test,
            epochs, verbose_epoch, learning_rate, weight_decay)
        train_loss_sum += train_loss
        print("Test loss: %f" % test_loss)
        test_loss_sum += test_loss
    return train_loss_sum / k, test_loss_sum / k

# %%
k = 5
epochs = 200
verbose_epoch = 90
learning_rate = 0.03
weight_decay = 200

# %%
train_loss, test_loss = k_fold_cross_valid(k, epochs, verbose_epoch, X_train, y_train, learning_rate, weight_decay)
print('%d-fold validation: avg train loss: %f, avg test loss: %f' %(k, train_loss, test_loss))
# Out:
# epoch 91, train loss: 0.121009
# epoch 92, train loss: 0.120352
# epoch 93, train loss: 0.119926
# epoch 94, train loss: 0.119863
# epoch 95, train loss: 0.120045
# epoch 96, train loss: 0.119929
# epoch 97, train loss: 0.119741
# epoch 98, train loss: 0.119898
# epoch 99, train loss: 0.119539
# epoch 100, train loss: 0.119068
# epoch 101, train loss: 0.119212
# epoch 102, train loss: 0.119350
# epoch 103, train loss: 0.118626
# epoch 104, train loss: 0.118308
# epoch 105, train loss: 0.118417
# epoch 106, train loss: 0.118342
# epoch 107, train loss: 0.118672
# epoch 108, train loss: 0.118623
# epoch 109, train loss: 0.118508
# epoch 110, train loss: 0.118556
# epoch 111, train loss: 0.118097
# epoch 112, train loss: 0.117637
# epoch 113, train loss: 0.117479
# epoch 114, train loss: 0.117457
# epoch 115, train loss: 0.117445
# epoch 116, train loss: 0.117301
# epoch 117, train loss: 0.116832
# epoch 118, train loss: 0.117109
# epoch 119, train loss: 0.116870
# epoch 120, train loss: 0.116938
# epoch 121, train loss: 0.116623
# epoch 122, train loss: 0.116450
# epoch 123, train loss: 0.116165
# epoch 124, train loss: 0.115979
# epoch 125, train loss: 0.115993
# epoch 126, train loss: 0.116026
# epoch 127, train loss: 0.116212
# epoch 128, train loss: 0.116050
# epoch 129, train loss: 0.115968
# epoch 130, train loss: 0.115662
# epoch 131, train loss: 0.115525
# epoch 132, train loss: 0.115688
# epoch 133, train loss: 0.115329
# epoch 134, train loss: 0.115038
# epoch 135, train loss: 0.115086
# epoch 136, train loss: 0.115108
# epoch 137, train loss: 0.114927
# epoch 138, train loss: 0.114696
# epoch 139, train loss: 0.114800
# epoch 140, train loss: 0.114474
# epoch 141, train loss: 0.114528
# epoch 142, train loss: 0.114364
# epoch 143, train loss: 0.114215
# epoch 144, train loss: 0.114179
# epoch 145, train loss: 0.114309
# epoch 146, train loss: 0.113960
# epoch 147, train loss: 0.114589
# epoch 148, train loss: 0.114321
# epoch 149, train loss: 0.114045
# epoch 150, train loss: 0.113352
# epoch 151, train loss: 0.113477
# epoch 152, train loss: 0.113300
# epoch 153, train loss: 0.113090
