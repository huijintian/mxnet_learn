# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20180301', periods=6)
dates
# Out:
# DatetimeIndex(['2018-03-01', '2018-03-02', '2018-03-03', '2018-03-04',
#                '2018-03-05', '2018-03-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2018-03-01  0.976746  0.182895  0.831184  0.340529
# 2018-03-02  0.938241  0.379869  0.592056  0.908773
# 2018-03-03  0.447302  0.309558  0.729988  0.464040
# 2018-03-04  0.648850  0.107207  0.461265  0.505596
# 2018-03-05  0.403541  0.098346  0.200327  0.849478
# 2018-03-06  0.921563  0.045185  0.409758  0.919100

# %%
df2 = pd.DataFrame({'A':1.,
                   'B': pd.Timestamp('20180301'),
                   'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                   'D': np.array([3] * 4, dtype='int32'),
                   'E': pd.Categorical(['test', 'train', 'test', 'train']),
                   'F': 'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2018-03-01  1.0  3   test  foo
# 1  1.0 2018-03-01  1.0  3  train  foo
# 2  1.0 2018-03-01  1.0  3   test  foo
# 3  1.0 2018-03-01  1.0  3  train  foo

# %% [markdown]
# 查看详情

# %%
df.head()
# Out:
#                    A         B         C         D
# 2018-03-01  0.976746  0.182895  0.831184  0.340529
# 2018-03-02  0.938241  0.379869  0.592056  0.908773
# 2018-03-03  0.447302  0.309558  0.729988  0.464040
# 2018-03-04  0.648850  0.107207  0.461265  0.505596
# 2018-03-05  0.403541  0.098346  0.200327  0.849478

# %%
df.tail(3) #查看最后几行
# Out:
#                    A         B         C         D
# 2018-03-04  0.648850  0.107207  0.461265  0.505596
# 2018-03-05  0.403541  0.098346  0.200327  0.849478
# 2018-03-06  0.921563  0.045185  0.409758  0.919100

# %%
df.index
# Out:
# DatetimeIndex(['2018-03-01', '2018-03-02', '2018-03-03', '2018-03-04',
#                '2018-03-05', '2018-03-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.97674594,  0.18289527,  0.83118442,  0.34052893],
#        [ 0.93824076,  0.37986872,  0.59205593,  0.90877254],
#        [ 0.44730191,  0.30955814,  0.72998799,  0.4640401 ],
#        [ 0.64884995,  0.10720664,  0.46126526,  0.50559616],
#        [ 0.40354085,  0.0983461 ,  0.20032696,  0.84947774],
#        [ 0.92156325,  0.04518457,  0.40975832,  0.91909987]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.722707  0.187177  0.537430  0.664586
# std    0.258343  0.131585  0.228951  0.256554
# min    0.403541  0.045185  0.200327  0.340529
# 25%    0.497689  0.100561  0.422635  0.474429
# 50%    0.785207  0.145051  0.526661  0.677537
# 75%    0.934071  0.277892  0.695505  0.893949
# max    0.976746  0.379869  0.831184  0.919100

# %%
df.T #转置
# Out:
#    2018-03-01  2018-03-02  2018-03-03  2018-03-04  2018-03-05  2018-03-06
# A    0.976746    0.938241    0.447302    0.648850    0.403541    0.921563
# B    0.182895    0.379869    0.309558    0.107207    0.098346    0.045185
# C    0.831184    0.592056    0.729988    0.461265    0.200327    0.409758
# D    0.340529    0.908773    0.464040    0.505596    0.849478    0.919100

# %%
df.sort_index(axis=1, ascending=False) # axis=1以列的名称来排列，降序
# Out:
#                    D         C         B         A
# 2018-03-01  0.340529  0.831184  0.182895  0.976746
# 2018-03-02  0.908773  0.592056  0.379869  0.938241
# 2018-03-03  0.464040  0.729988  0.309558  0.447302
# 2018-03-04  0.505596  0.461265  0.107207  0.648850
# 2018-03-05  0.849478  0.200327  0.098346  0.403541
# 2018-03-06  0.919100  0.409758  0.045185  0.921563

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2018-03-06  0.921563  0.045185  0.409758  0.919100
# 2018-03-05  0.403541  0.098346  0.200327  0.849478
# 2018-03-04  0.648850  0.107207  0.461265  0.505596
# 2018-03-01  0.976746  0.182895  0.831184  0.340529
# 2018-03-03  0.447302  0.309558  0.729988  0.464040
# 2018-03-02  0.938241  0.379869  0.592056  0.908773

# %%
df['A']
# Out:
# 2018-03-01    0.976746
# 2018-03-02    0.938241
# 2018-03-03    0.447302
# 2018-03-04    0.648850
# 2018-03-05    0.403541
# 2018-03-06    0.921563
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2018-03-01  0.976746  0.182895  0.831184  0.340529
# 2018-03-02  0.938241  0.379869  0.592056  0.908773
# 2018-03-03  0.447302  0.309558  0.729988  0.464040

# %%
df['20180302':'20180305']
# Out:
#                    A         B         C         D
# 2018-03-02  0.938241  0.379869  0.592056  0.908773
# 2018-03-03  0.447302  0.309558  0.729988  0.464040
# 2018-03-04  0.648850  0.107207  0.461265  0.505596
# 2018-03-05  0.403541  0.098346  0.200327  0.849478

# %%
df.loc[dates[0]]  # 取第一行的数据
# Out:
# A    0.976746
# B    0.182895
# C    0.831184
# D    0.340529
# Name: 2018-03-01 00:00:00, dtype: float64

# %%
df.loc[:,['A', 'B']]  #取得A、B列的所有数据
# Out:
#                    A         B
# 2018-03-01  0.976746  0.182895
# 2018-03-02  0.938241  0.379869
# 2018-03-03  0.447302  0.309558
# 2018-03-04  0.648850  0.107207
# 2018-03-05  0.403541  0.098346
# 2018-03-06  0.921563  0.045185

# %%
df.loc['20180301':'20180304', ['A', 'C']]
# Out:
#                    A         C
# 2018-03-01  0.976746  0.831184
# 2018-03-02  0.938241  0.592056
# 2018-03-03  0.447302  0.729988
# 2018-03-04  0.648850  0.461265

# %%
df.loc[dates[0], 'A']
# Out:
# 0.97674593801846632

# %%
df.at[dates[0], 'A']
# Out:
# 0.97674593801846632

# %%
df
# Out:
#                    A         B         C         D
# 2018-03-01  0.976746  0.182895  0.831184  0.340529
# 2018-03-02  0.938241  0.379869  0.592056  0.908773
# 2018-03-03  0.447302  0.309558  0.729988  0.464040
# 2018-03-04  0.648850  0.107207  0.461265  0.505596
# 2018-03-05  0.403541  0.098346  0.200327  0.849478
# 2018-03-06  0.921563  0.045185  0.409758  0.919100

# %%
df.iloc[3]
# Out:
# A    0.648850
# B    0.107207
# C    0.461265
# D    0.505596
# Name: 2018-03-04 00:00:00, dtype: float64

# %%
df[df.A > 0.5]
# Out:
#                    A         B         C         D
# 2018-03-01  0.976746  0.182895  0.831184  0.340529
# 2018-03-02  0.938241  0.379869  0.592056  0.908773
# 2018-03-04  0.648850  0.107207  0.461265  0.505596
# 2018-03-06  0.921563  0.045185  0.409758  0.919100

# %%
df[df > 0.5]
# Out:
#                    A   B         C         D
# 2018-03-01  0.976746 NaN  0.831184       NaN
# 2018-03-02  0.938241 NaN  0.592056  0.908773
# 2018-03-03       NaN NaN  0.729988       NaN
# 2018-03-04  0.648850 NaN       NaN  0.505596
# 2018-03-05       NaN NaN       NaN  0.849478
# 2018-03-06  0.921563 NaN       NaN  0.919100

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2018-03-01  0.976746  0.182895  0.831184  0.340529    one
# 2018-03-02  0.938241  0.379869  0.592056  0.908773    one
# 2018-03-03  0.447302  0.309558  0.729988  0.464040    two
# 2018-03-04  0.648850  0.107207  0.461265  0.505596  three
# 2018-03-05  0.403541  0.098346  0.200327  0.849478   four
# 2018-03-06  0.921563  0.045185  0.409758  0.919100  three

# %%
df2[df2['E'].isin(['two', 'four'])]
# Out:
#                    A         B         C         D     E
# 2018-03-03  0.447302  0.309558  0.729988  0.464040   two
# 2018-03-05  0.403541  0.098346  0.200327  0.849478  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20180301', periods=6))
s1
# Out:
# 2018-03-01    1
# 2018-03-02    2
# 2018-03-03    3
# 2018-03-04    4
# 2018-03-05    5
# 2018-03-06    6
# Freq: D, dtype: int64

# %%
df['F'] = s1
df
# Out:
#                    A         B         C         D  F
# 2018-03-01  0.976746  0.182895  0.831184  0.340529  1
# 2018-03-02  0.938241  0.379869  0.592056  0.908773  2
# 2018-03-03  0.447302  0.309558  0.729988  0.464040  3
# 2018-03-04  0.648850  0.107207  0.461265  0.505596  4
# 2018-03-05  0.403541  0.098346  0.200327  0.849478  5
# 2018-03-06  0.921563  0.045185  0.409758  0.919100  6

# %% [markdown]
# 统计

# %%
df.mean() #描述性统计
# Out:
# A    0.722707
# B    0.187177
# C    0.537430
# D    0.664586
# F    3.500000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2018-03-01    0.666271
# 2018-03-02    0.963788
# 2018-03-03    0.990178
# 2018-03-04    1.144584
# 2018-03-05    1.310338
# 2018-03-06    1.659121
# Freq: D, dtype: float64

# %%
df.mean(0)
# Out:
# A    0.722707
# B    0.187177
# C    0.537430
# D    0.664586
# F    3.500000
# dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2018-03-01    NaN
# 2018-03-02    NaN
# 2018-03-03    1.0
# 2018-03-04    3.0
# 2018-03-05    5.0
# 2018-03-06    NaN
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C         D  F
# 2018-03-01  0.976746  0.182895  0.831184  0.340529  1
# 2018-03-02  0.938241  0.379869  0.592056  0.908773  2
# 2018-03-03  0.447302  0.309558  0.729988  0.464040  3
# 2018-03-04  0.648850  0.107207  0.461265  0.505596  4
# 2018-03-05  0.403541  0.098346  0.200327  0.849478  5
# 2018-03-06  0.921563  0.045185  0.409758  0.919100  6

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C         D    F
# 2018-03-01       NaN       NaN       NaN       NaN  NaN
# 2018-03-02       NaN       NaN       NaN       NaN  NaN
# 2018-03-03 -0.552698 -0.690442 -0.270012 -0.535960  2.0
# 2018-03-04 -2.351150 -2.892793 -2.538735 -2.494404  1.0
# 2018-03-05 -4.596459 -4.901654 -4.799673 -4.150522  0.0
# 2018-03-06       NaN       NaN       NaN       NaN  NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C         D   F
# 2018-03-01  0.976746  0.182895  0.831184  0.340529   1
# 2018-03-02  1.914987  0.562764  1.423240  1.249301   3
# 2018-03-03  2.362289  0.872322  2.153228  1.713342   6
# 2018-03-04  3.011139  0.979529  2.614494  2.218938  10
# 2018-03-05  3.414679  1.077875  2.814821  3.068415  15
# 2018-03-06  4.336243  1.123059  3.224579  3.987515  21

# %% [markdown]
# join

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %% [markdown]
# append

# %%
df = pd.DataFrame(np.random.rand(8, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.087057  0.309299  0.676787  0.261225
# 1  0.254954  0.484948  0.722504  0.852810
# 2  0.773719  0.939813  0.111006  0.831365
# 3  0.214843  0.025982  0.727466  0.417231
# 4  0.058067  0.118559  0.201165  0.582715
# 5  0.489664  0.421996  0.353690  0.231954
# 6  0.271503  0.275720  0.448922  0.910861
# 7  0.514330  0.719466  0.287454  0.861414

# %%
df.loc[3]
# Out:
# A    0.214843
# B    0.025982
# C    0.727466
# D    0.417231
# Name: 3, dtype: float64

# %%
s = df.iloc[3]
s
# Out:
# A    0.214843
# B    0.025982
# C    0.727466
# D    0.417231
# Name: 3, dtype: float64

# %%
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.087057  0.309299  0.676787  0.261225
# 1  0.254954  0.484948  0.722504  0.852810
# 2  0.773719  0.939813  0.111006  0.831365
# 3  0.214843  0.025982  0.727466  0.417231
# 4  0.058067  0.118559  0.201165  0.582715
# 5  0.489664  0.421996  0.353690  0.231954
# 6  0.271503  0.275720  0.448922  0.910861
# 7  0.514330  0.719466  0.287454  0.861414
# 8  0.214843  0.025982  0.727466  0.417231

# %% [markdown]
# grouping

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                  'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                  'C': np.random.randn(8),
                  'D': np.random.randn(8)}) # randn(8) 这里怎么必须是8？。。。
df
# Out:
#      A      B         C         D
# 0  foo    one -2.122238 -0.135402
# 1  bar    one  0.719595  0.090997
# 2  foo    two  0.034514 -0.601592
# 3  bar  three -1.348928  0.604410
# 4  foo    two  0.047054  1.729313
# 5  bar    two -1.859986 -1.212774
# 6  foo    one -0.825950  1.462022
# 7  foo  three -1.159535 -0.669062

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -2.489319 -0.517368
# foo -4.026156  1.785279

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.719595  0.090997
#     three -1.348928  0.604410
#     two   -1.859986 -1.212774
# foo one   -2.948188  1.326620
#     three -1.159535 -0.669062
#     two    0.081568  1.127721

# %% [markdown]
# 绘图

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure();df.plot();plt.legend(loc='best')

# %% [markdown]
# 数据存储读取

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A          B          C          D
# 0    2000-01-01   0.910550  -1.415650   1.239225  -0.088497
# 1    2000-01-02   1.464813  -0.020158   2.015349   0.642840
# 2    2000-01-03   1.631212  -0.865271   0.259386   0.341166
# 3    2000-01-04   3.010439  -0.052944   0.342840  -0.242931
# 4    2000-01-05   3.981363  -0.016317  -1.264023  -1.221811
# 5    2000-01-06   3.648889   0.717067  -1.801666  -1.194916
# 6    2000-01-07   3.242144   1.880679  -1.139654  -3.337619
# 7    2000-01-08   2.583633   0.383645  -2.237631  -2.720573
# 8    2000-01-09   0.803818   1.316392  -2.460090  -2.669617
# 9    2000-01-10   1.911315  -0.785425  -2.265701  -2.722608
# 10   2000-01-11   1.910653  -1.030372  -2.576412  -2.997357
# 11   2000-01-12   2.189452  -0.493769  -3.158323  -3.883930
# 12   2000-01-13   1.984578  -0.261515  -2.218535  -3.699466
# 13   2000-01-14   1.566964  -2.833882  -1.780628  -4.742508
# 14   2000-01-15   1.945979  -2.256094  -4.070492  -3.802914
# ...
